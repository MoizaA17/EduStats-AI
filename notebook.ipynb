# %% [markdown]
# # EduStats AI - Development Notebook
#
# Purpose:
# - Test NumPy logic
# - Learn Streamlit concepts
# - Experiment before adding code to app.py

# %% [markdown]
# # Sprint 1
#
# Goal:
# Learn the basic Streamlit commands used in the project.
#
# -st.title(...)
#
# -st.write(...)
#
# -st.button(...)
#
# -st.text_input(...)

# %%
import streamlit as st
import numpy as np

# %%
user_input = "55, 67, 56, 90, 45"

marks = user_input.split(",")

students_marks = [int(mark) for mark in marks]

print(students_marks)
# Out:
# [55, 67, 56, 90, 45]

# %%
students_marks = np.array(students_marks)

average = students_marks.mean()
print("Average: ", average)

highest = students_marks.max()
print("Highest Marks: ", highest)

lowest = students_marks.min()
print("Lowest Marks: ", lowest)

topper_index = students_marks.argmax()
print("Topper Student: ", topper_index + 1)
print("Marks: ",students_marks[topper_index])

passed_students = students_marks[students_marks>=50]
print("Passed Students: ", passed_students)

failed_students = students_marks[students_marks<50]
print("Failed Students: ", failed_students)

pass_percentage = (len(passed_students)/len(students_marks)) * 100
print("Percentage of Passed Students: ", pass_percentage)
# Out:
# Average:  62.6
# Highest Marks:  90
# Lowest Marks:  45
# Topper Student:  4
# Marks:  90
# Passed Students:  [55 67 56 90]
# Failed Students:  [45]
# Percentage of Passed Students:  80.0

# %% [markdown]
# **st.button()** sirf button banata nahi, balki tumhe batata bhi hai ke user ne us button ko click kiya ya nahi.
